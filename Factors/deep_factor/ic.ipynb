# %%
import pandas as pd
import torch
import numpy as np
import matplotlib.pyplot as plt
import sys
from tqdm import tqdm
import os
from torch import nn
sys.path.append('..')

# %%
ic = np.loadtxt('./test_11/results/lstm_SH_6/ic.csv')

# %%
res = []
for i in range(ic.shape[-1]):
    res.append(ic[:,i].mean())
plt.plot(res)
plt.title('ic mean each moment')
plt.show()

# %%
len(res)
# Out:
# 42

# %%
ic.mean()
# Out:
# 0.09021219069411268

# %%
res = []
for i in range(ic.shape[0]):
    res.append(ic[i].mean())
plt.plot(res)
plt.title('ic mean each day')
plt.show()

# %% [markdown]
# 单因子的ic_mean

# %%
#246: /home/largefile/public/ic/rank_ic_1min.csv
df = pd.read_csv('../IC/rank_ic_1min.csv', index_col=0)
columns = list(df.columns)
idx = columns.index('var_10')
columns = columns[idx:]
df = df.loc[:, columns]

# %%
iter_obj = iter(range(0, 49))

# %%
idx = next(iter_obj)
arr = df.iloc[:, idx].values.reshape(-1, 240)
plt.plot(arr.mean(axis=0))
plt.title(f'{idx}: {columns[idx]}')
plt.show()
idx += 12 
arr = df.iloc[:, idx].values.reshape(-1, 240)
plt.plot(arr.mean(axis=0))
plt.title(f'{idx}: {columns[idx]}')
plt.show()
idx += 12 
arr = df.iloc[:, idx].values.reshape(-1, 240)
plt.plot(arr.mean(axis=0))
plt.title(f'{idx}: {columns[idx]}')
plt.show()

# %%
iter_obj = iter(range(43, 49))

# %%
idx = next(iter_obj)
arr = df.iloc[:, idx].values.reshape(-1, 240)
plt.plot(arr.mean(axis=0))
plt.title(f'{idx}: {columns[idx]}')
plt.show()

# %% [markdown]
# 单因子的ic_std

# %%
df = pd.read_csv('../IC/rank_ic_1min.csv', index_col=0)
columns = list(df.columns)
idx = columns.index('var_10')
columns = columns[idx:]
df = df.loc[:, columns]

# %%
iter_obj = iter(range(0, 49))

# %%
idx = next(iter_obj)
arr = df.iloc[:, idx].values.reshape(-1, 240)
plt.plot(arr.std(axis=0))
plt.title(f'{idx}: {columns[idx]}')
plt.show()
idx += 12 
arr = df.iloc[:, idx].values.reshape(-1, 240)
plt.plot(arr.std(axis=0))
plt.title(f'{idx}: {columns[idx]}')
plt.show()
idx += 12 
arr = df.iloc[:, idx].values.reshape(-1, 240)
plt.plot(arr.std(axis=0))
plt.title(f'{idx}: {columns[idx]}')
plt.show()

# %%
iter_obj = iter(range(43, 49))

# %%
idx = next(iter_obj)
arr = df.iloc[:, idx].values.reshape(-1, 240)
plt.plot(arr.mean(axis=0))
plt.title(f'{idx}: {columns[idx]}')
plt.show()

# %% [markdown]
# 单因子的ic_ir

# %%
df = pd.read_csv('../IC/rank_ic_1min.csv', index_col=0)
columns = list(df.columns)
idx = columns.index('var_10')
columns = columns[idx:]
df = df.loc[:, columns]

# %%
iter_obj = iter(range(0, 49))

# %%
idx = next(iter_obj)
arr = df.iloc[:, idx].values.reshape(-1, 240)
plt.plot(arr.std(axis=0)/arr.mean(axis=0))
plt.title(f'{idx}: {columns[idx]}')
plt.show()

# %%
(arr.std(axis=0)/arr.mean(axis=0))[40:45]
# Out:
# array([-21.765011  ,  -9.43597721,  -5.61137416,  -4.84157126,
#         -4.71852104])

# %% [markdown]
# 看单个因子某个时刻的分布图
